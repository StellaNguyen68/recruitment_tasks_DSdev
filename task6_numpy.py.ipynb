# %%
import random
import numpy as np
import matplotlib.pyplot as plt



nsteps = 100
draws =np.random.randint(0, 2, size = nsteps)
steps = np.where(draws > 0,1,-1)
walk = np.append([0],steps.cumsum())

# %%
walk
# Out:
# array([  0,  -1,  -2,  -1,  -2,  -1,   0,  -1,   0,  -1,  -2,  -1,   0,
#          1,   0,   1,   0,   1,   0,   1,   2,   3,   2,   3,   2,   1,
#          2,   1,   0,  -1,  -2,  -3,  -2,  -3,  -2,  -3,  -2,  -3,  -4,
#         -5,  -4,  -5,  -4,  -5,  -6,  -7,  -8,  -9, -10, -11, -12, -11,
#        -12, -11, -12, -11, -12, -13, -12, -13, -12, -11, -12, -11, -10,
#         -9,  -8,  -9,  -8,  -9,  -8,  -7,  -6,  -5,  -6,  -7,  -8,  -9,
#         -8,  -9, -10,  -9, -10, -11, -12, -11, -10, -11, -10,  -9, -10,
#         -9, -10,  -9,  -8,  -7,  -6,  -7,  -8,  -9,  -8])

# %%
plt.plot(walk)

# %%
walk.min()
# Out:
# -8

# %%
walk.max()
# Out:
# 1

# %%
nwalks = 50
nsteps = 100
draws = np.random.randint(0,2,size = (nwalks,nsteps))
steps = np.where(draws >0,1,-1)
walks = steps.cumsum(1)
walks
# Out:
# array([[ 1,  2,  1, ...,  2,  3,  4],
#        [ 1,  0,  1, ...,  6,  7,  6],
#        [ 1,  2,  1, ..., -4, -3, -4],
#        ...,
#        [ 1,  0, -1, ...,  4,  3,  2],
#        [ 1,  0, -1, ..., 14, 13, 14],
#        [-1,  0,  1, ...,  0,  1,  0]], dtype=int32)

# %%
hits30 = (np.abs(walks) >=30).any(1)
hits30.sum()
# Out:
# 0

# %%
plt.plot(walks)
# Out:
# [<matplotlib.lines.Line2D at 0x2039763f8b0>,
#  <matplotlib.lines.Line2D at 0x2039763f970>,
#  <matplotlib.lines.Line2D at 0x2039763fa30>,
#  <matplotlib.lines.Line2D at 0x2039763faf0>,
#  <matplotlib.lines.Line2D at 0x2039763fbb0>,
#  <matplotlib.lines.Line2D at 0x2039763fc70>,
#  <matplotlib.lines.Line2D at 0x2039763fd30>,
#  <matplotlib.lines.Line2D at 0x2039763fdf0>,
#  <matplotlib.lines.Line2D at 0x2039763feb0>,
#  <matplotlib.lines.Line2D at 0x2039763ff70>,
#  <matplotlib.lines.Line2D at 0x2039749dc70>,
#  <matplotlib.lines.Line2D at 0x2039764b100>,
#  <matplotlib.lines.Line2D at 0x2039764b1c0>,
#  <matplotlib.lines.Line2D at 0x2039764b280>,
#  <matplotlib.lines.Line2D at 0x2039764b340>,
#  <matplotlib.lines.Line2D at 0x2039764b400>,
#  <matplotlib.lines.Line2D at 0x2039764b4c0>,
#  <matplotlib.lines.Line2D at 0x2039764b580>,
#  <matplotlib.lines.Line2D at 0x2039764b640>,
#  <matplotlib.lines.Line2D at 0x2039764b700>,
#  <matplotlib.lines.Line2D at 0x2039764b7c0>,
#  <matplotlib.lines.Line2D at 0x2039764b880>,
#  <matplotlib.lines.Line2D at 0x2039764b940>,
#  <matplotlib.lines.Line2D at 0x2039764ba00>,
#  <matplotlib.lines.Line2D at 0x2039764bac0>,
#  <matplotlib.lines.Line2D at 0x2039764bb80>,
#  <matplotlib.lines.Line2D at 0x2039764bc40>,
#  <matplotlib.lines.Line2D at 0x2039764bd00>,
#  <matplotlib.lines.Line2D at 0x2039764bdc0>,
#  <matplotlib.lines.Line2D at 0x2039764be80>,
#  <matplotlib.lines.Line2D at 0x2039764bf40>,
#  <matplotlib.lines.Line2D at 0x20397652040>,
#  <matplotlib.lines.Line2D at 0x20397652100>,
#  <matplotlib.lines.Line2D at 0x203976521c0>,
#  <matplotlib.lines.Line2D at 0x20397652280>,
#  <matplotlib.lines.Line2D at 0x20397652340>,
#  <matplotlib.lines.Line2D at 0x20397652400>,
#  <matplotlib.lines.Line2D at 0x203976524c0>,
#  <matplotlib.lines.Line2D at 0x20397652580>,
#  <matplotlib.lines.Line2D at 0x20397652640>,
#  <matplotlib.lines.Line2D at 0x20397652700>,
#  <matplotlib.lines.Line2D at 0x203976527c0>,
#  <matplotlib.lines.Line2D at 0x20397652880>,
#  <matplotlib.lines.Line2D at 0x20397652940>,
#  <matplotlib.lines.Line2D at 0x20397652a30>,
#  <matplotlib.lines.Line2D at 0x20397652af0>,
#  <matplotlib.lines.Line2D at 0x20397652bb0>,
#  <matplotlib.lines.Line2D at 0x20397652c70>,
#  <matplotlib.lines.Line2D at 0x20397652d30>,
#  <matplotlib.lines.Line2D at 0x20397652df0>,
#  <matplotlib.lines.Line2D at 0x20397652eb0>,
#  <matplotlib.lines.Line2D at 0x20397652f70>,
#  <matplotlib.lines.Line2D at 0x20397658070>,
#  <matplotlib.lines.Line2D at 0x20397658130>,
#  <matplotlib.lines.Line2D at 0x203976581f0>,
#  <matplotlib.lines.Line2D at 0x203976582b0>,
#  <matplotlib.lines.Line2D at 0x20397658370>,
#  <matplotlib.lines.Line2D at 0x20397658430>,
#  <matplotlib.lines.Line2D at 0x203976584f0>,
#  <matplotlib.lines.Line2D at 0x203976585b0>,
#  <matplotlib.lines.Line2D at 0x20397658670>,
#  <matplotlib.lines.Line2D at 0x20397658730>,
#  <matplotlib.lines.Line2D at 0x203976587f0>,
#  <matplotlib.lines.Line2D at 0x203976588b0>,
#  <matplotlib.lines.Line2D at 0x20397658970>,
#  <matplotlib.lines.Line2D at 0x20397658a30>,
#  <matplotlib.lines.Line2D at 0x20397658af0>,
#  <matplotlib.lines.Line2D at 0x20397658bb0>,
#  <matplotlib.lines.Line2D at 0x20397658c70>,
#  <matplotlib.lines.Line2D at 0x20397658d30>,
#  <matplotlib.lines.Line2D at 0x20397658df0>,
#  <matplotlib.lines.Line2D at 0x20397658eb0>,
#  <matplotlib.lines.Line2D at 0x20397658f70>,
#  <matplotlib.lines.Line2D at 0x2039765f070>,
#  <matplotlib.lines.Line2D at 0x2039765f130>,
#  <matplotlib.lines.Line2D at 0x2039765f1f0>,
#  <matplotlib.lines.Line2D at 0x2039765f2b0>,
#  <matplotlib.lines.Line2D at 0x2039765f370>,
#  <matplotlib.lines.Line2D at 0x2039765f430>,
#  <matplotlib.lines.Line2D at 0x2039765f4f0>,
#  <matplotlib.lines.Line2D at 0x2039765f5b0>,
#  <matplotlib.lines.Line2D at 0x2039765f670>,
#  <matplotlib.lines.Line2D at 0x2039765f730>,
#  <matplotlib.lines.Line2D at 0x2039765f7f0>,
#  <matplotlib.lines.Line2D at 0x2039765f8b0>,
#  <matplotlib.lines.Line2D at 0x2039765f970>,
#  <matplotlib.lines.Line2D at 0x2039765fa30>,
#  <matplotlib.lines.Line2D at 0x2039765faf0>,
#  <matplotlib.lines.Line2D at 0x2039765fbb0>,
#  <matplotlib.lines.Line2D at 0x2039765fc70>,
#  <matplotlib.lines.Line2D at 0x2039765fd30>,
#  <matplotlib.lines.Line2D at 0x2039765fdf0>,
#  <matplotlib.lines.Line2D at 0x2039765feb0>,
#  <matplotlib.lines.Line2D at 0x2039765ff70>,
#  <matplotlib.lines.Line2D at 0x20397666070>,
#  <matplotlib.lines.Line2D at 0x20397666130>,
#  <matplotlib.lines.Line2D at 0x203976661f0>,
#  <matplotlib.lines.Line2D at 0x203976662b0>,
#  <matplotlib.lines.Line2D at 0x20397666370>,
#  <matplotlib.lines.Line2D at 0x20397666430>]
